# %% [markdown]
# <a href="https://colab.research.google.com/github/MayarQasrawi/Artificial-Intelligent/blob/main/RegularizationExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso

# %% [markdown]
# ### 1. Load in the data
#
# The data is in the file called 'data.csv'. Note that there's no header row on this file.
# Split the data so that the six predictor features (first six columns) are stored in X, and the outcome feature (last column) is stored in y.

# %%
train_data=pd.read_csv('/data (1).csv',header=None)
x=train_data.iloc[:,0:6]
y=train_data.iloc[:,6]

# %%
x
# Out:
#            0        1         2        3        4        5
# 0    1.25664  2.04978  -6.23640  4.71926 -4.26931  0.20590
# 1   -3.89012 -0.37511   6.14979  4.94585 -3.57844  0.00640
# 2    5.09784  0.98120  -0.29939  5.85805  0.28297 -0.20626
# 3    0.39034 -3.06861  -5.63488  6.43941  0.39256 -0.07084
# 4    5.84727 -0.15922  11.41246  7.52165  1.69886  0.29022
# ..       ...      ...       ...      ...      ...      ...
# 95  -4.58240 -1.27825   7.55098  8.83930 -3.80318  0.04386
# 96 -10.00364  2.66002  -4.26776 -3.73792 -0.72349 -0.24617
# 97  -4.32624 -2.30314  -8.16044  4.46366 -3.33569 -0.01655
# 98  -1.90167 -0.15858 -10.43466  4.89762 -0.64606 -0.14519
# 99   2.43213  2.41613   2.49949 -8.03891 -1.64164 -0.63444
#
# [100 rows x 6 columns]

# %%
y
# Out:
# 0     12.31798
# 1     23.67628
# 2     -1.53459
# 3    -24.68670
# 4     17.54122
#         ...
# 95    26.14768
# 96     0.76214
# 97   -10.05262
# 98   -19.63970
# 99    12.76193
# Name: 6, Length: 100, dtype: float64

# %%
train_data.head()
# Out:
#          0        1         2        3        4        5         6
# 0  1.25664  2.04978  -6.23640  4.71926 -4.26931  0.20590  12.31798
# 1 -3.89012 -0.37511   6.14979  4.94585 -3.57844  0.00640  23.67628
# 2  5.09784  0.98120  -0.29939  5.85805  0.28297 -0.20626  -1.53459
# 3  0.39034 -3.06861  -5.63488  6.43941  0.39256 -0.07084 -24.68670
# 4  5.84727 -0.15922  11.41246  7.52165  1.69886  0.29022  17.54122

# %%
train_data.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    -0.076288   -0.181381    0.339573    1.772602   -0.168269    0.009754
# std      5.560089    1.737693    4.982072    8.163906    3.184054    0.183237
# min    -12.398240   -5.280250  -11.235910  -23.820240   -6.865330   -0.634440
# 25%     -3.880408   -1.222918   -2.833322   -3.383100   -2.731047   -0.099910
# 50%     -0.009940   -0.278235   -0.072670    0.711860   -0.120520    0.002385
# 75%      4.065705    1.083133    3.855920    6.704855    2.173942    0.119822
# max     13.374540    4.301200   11.946500   22.880080    7.351290    0.523280
#
#                 6
# count  100.000000
# mean     0.744579
# std     17.132932
# min    -45.017100
# 25%     -9.455507
# 50%      0.415680
# 75%     12.878975
# max     36.216980

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       100 non-null    float64
#  1   1       100 non-null    float64
#  2   2       100 non-null    float64
#  3   3       100 non-null    float64
#  4   4       100 non-null    float64
#  5   5       100 non-null    float64
#  6   6       100 non-null    float64
# dtypes: float64(7)
# memory usage: 5.6 KB

# %% [markdown]
# ### 2. (NEW) Perform feature scaling on data via standardization
#
# Create an instance of sklearn's `StandardScaler` and assign it to the variable `scaler`.
# Compute the scaling parameters by using the `.fit_transform()` method on the predictor feature array, which also returns the predictor variables in their standardized values. Store those standardized values in `X_scaled`.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(x)

# %% [markdown]
# ### 2. Fit data using linear regression with Lasso regularization
#
# Create an instance of sklearn's `Lasso`(opens in a new tab) class and assign it to the variable `lasso_reg`.
# You don't need to set any parameter values: use the default values for the quiz.
# Use the Lasso object's `.fit()` method to fit the regression model onto the data.

# %%
lasso_reg= Lasso()
lasso_reg.fit(X_scaled,y)
# Out:
# Lasso()

# %% [markdown]
# ### 3. Inspect the coefficients of the regression model
#
# Obtain the coefficients of the fit regression model using the `.coef_` attribute of the Lasso object. Store this in the `reg_coef` variable: the coefficients will be printed out, and you will use your observations to answer the question at the bottom of the page.

# %%
reg_coef=lasso_reg.coef_
reg_coef
# Out:
# array([  0.        ,   3.90753617,   9.02575748,  -0.        ,
#        -11.78303187,   0.45340137])

# %% [markdown]
# `Lasso` regularization has set the coefficients for the first and sixth columns to 0.
# You might try fitting the model to a standard linear regression to see the coefficients before regularization!

# %%
from  sklearn.linear_model import LinearRegression
Model=LinearRegression()
Model.fit(x,y)

Model.coef_
# Out:
# array([-6.19918532e-03,  2.96325160e+00,  1.98199191e+00, -7.86249920e-02,
#        -3.95818772e+00,  9.30786141e+00])
